# %%
from aleph_alpha_client import AlephAlphaModel
model = AlephAlphaModel.from_model_name(model_name="luminous-extended", token="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjo3MTg0LCJ0b2tlbl9pZCI6ODczfQ.xmwT52tlCJFAIeRfbtGgZY9Q4XUH6fR4CANkd14n2iY")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\Users\M0201420\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\Users\M0201420\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\M0201420\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
# ...

# %%
from aleph_alpha_client import Prompt
prompt = Prompt("Q: What is AI? A:")
